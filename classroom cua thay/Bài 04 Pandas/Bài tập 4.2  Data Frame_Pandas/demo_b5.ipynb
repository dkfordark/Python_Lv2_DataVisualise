# %%
import numpy as np
import pandas as pd

# %%
lst = [1,2,3]
df1 = pd.DataFrame(lst)
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
print(df1)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
lst = [['An',18],['Trung',20],['Dao',17]]
df2 = pd.DataFrame(lst,columns=['Name','Age'],index=['sv1','sv2','sv3'])
df2
# Out:
#       Name  Age
# sv1     An   18
# sv2  Trung   20
# sv3    Dao   17

# %%
dic = {'name':['An','Lan','Hoa'],'age':[16,17,18]}
df3 = pd.DataFrame(dic,columns=['name','class'],index=['sv1','sv2','sv3'])
df3
# Out:
#     name class
# sv1   An   NaN
# sv2  Lan   NaN
# sv3  Hoa   NaN

# %%
dic = {'one':pd.Series([1,2,3,9],index=['a','b','c','e']),
       'two':pd.Series([5,6,7,8],index=['a','b','c','d']),
       'three':pd.Series([7,9,3],index=['a','b','c'])}

# %%
df4 = pd.DataFrame(dic)
df4
# Out:
#    one  two  three
# a  1.0  5.0    7.0
# b  2.0  6.0    9.0
# c  3.0  7.0    3.0
# d  NaN  8.0    NaN
# e  9.0  NaN    NaN

# %%
df4['one']
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# e    9.0
# Name: one, dtype: float64

# %%
df4.one
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# e    9.0
# Name: one, dtype: float64

# %%
df4[['one','three']]
# Out:
#    one  three
# a  1.0    7.0
# b  2.0    9.0
# c  3.0    3.0
# d  NaN    NaN
# e  9.0    NaN

# %%
df4
# Out:
#    one  two  three
# a  1.0  5.0    7.0
# b  2.0  6.0    9.0
# c  3.0  7.0    3.0
# d  NaN  8.0    NaN
# e  9.0  NaN    NaN

# %%
df4['four'] = pd.Series([1,2,3,4,5,6],index=['a','b','c','d','e','f'])
df4
# Out:
#    one  two  three  four
# a  1.0  5.0    7.0     1
# b  2.0  6.0    9.0     2
# c  3.0  7.0    3.0     3
# d  NaN  8.0    NaN     4
# e  9.0  NaN    NaN     5

# %%
df4['ive'] = df4['four'] + 1
df4
# Out:
#    one  two  three  four  five
# a  1.0  5.0    7.0     1     2
# b  2.0  6.0    9.0     2     3
# c  3.0  7.0    3.0     3     4
# d  NaN  8.0    NaN     4     5
# e  9.0  NaN    NaN     5     6

# %%
df4['six'] = df4['four'].map(lambda x : x**2)
df4
# Out:
#    one  two  three  four  five  six
# a  1.0  5.0    7.0     1     2    1
# b  2.0  6.0    9.0     2     3    4
# c  3.0  7.0    3.0     3     4    9
# d  NaN  8.0    NaN     4     5   16
# e  9.0  NaN    NaN     5     6   25

# %%
t = df4.pop('five')

# %%
df4
# Out:
#    one  two  three  four  six
# a  1.0  5.0    7.0     1    1
# b  2.0  6.0    9.0     2    4
# c  3.0  7.0    3.0     3    9
# d  NaN  8.0    NaN     4   16
# e  9.0  NaN    NaN     5   25

# %%
t
# Out:
# a    2
# b    3
# c    4
# d    5
# e    6
# Name: five, dtype: int64

# %%
df5 = df4.drop(['four','six'],axis=1)
df5
# Out:
#    one  two  three
# a  1.0  5.0    7.0
# b  2.0  6.0    9.0
# c  3.0  7.0    3.0
# d  NaN  8.0    NaN
# e  9.0  NaN    NaN

# %%
df4
# Out:
#    one  two  three  four  six
# a  1.0  5.0    7.0     1    1
# b  2.0  6.0    9.0     2    4
# c  3.0  7.0    3.0     3    9
# d  NaN  8.0    NaN     4   16
# e  9.0  NaN    NaN     5   25

# %%
df4.loc[['a','b','c']]
# Out:
#    one  two  three  four  six
# a  1.0  5.0    7.0     1    1
# b  2.0  6.0    9.0     2    4
# c  3.0  7.0    3.0     3    9

# %%
df4.iloc[:3,:3]
# Out:
#    one  two  three
# a  1.0  5.0    7.0
# b  2.0  6.0    9.0
# c  3.0  7.0    3.0

# %%
df4
# Out:
#    one  two  three  four  six
# a  1.0  5.0    7.0     1    1
# b  2.0  6.0    9.0     2    4
# c  3.0  7.0    3.0     3    9
# d  NaN  8.0   10.0     4   16
# e  9.0  NaN    NaN     5   25

# %%
# loc[index label , columns label]
# iloc [row index,columns index ]
df4.loc['d','three'] = 10

# %%
df4.iloc[4,1] = np.nan
df4
# Out:
#    one  two  three  four  six
# a  1.0  5.0    7.0     1    1
# b  2.0  6.0    9.0     2    4
# c  3.0  7.0    3.0     3    9
# d  NaN  8.0   10.0     4   16
# e  9.0  NaN    NaN     5   25

# %%
df4.loc['e',['two','three']] = 11
df4
# Out:
#    one   two  three  four  six
# a  1.0   5.0    7.0     1    1
# b  2.0   6.0    9.0     2    4
# c  3.0   7.0    3.0     3    9
# d  NaN   8.0   10.0     4   16
# e  9.0  11.0   11.0     5   25

# %%
df4.loc[df4['three'] > 7,['three','four']]
# Out:
#    three  four
# b    9.0     2
# d   10.0     4
# e   11.0     5

# %%
df4[df4['three'] > 7]
# Out:
#    one   two  three  four  six
# b  2.0   6.0    9.0     2    4
# d  NaN   8.0   10.0     4   16
# e  9.0  11.0   11.0     5   25

# %%
df4
# Out:
#    one   two  three  four  six
# a  1.0   5.0    7.0     1    1
# b  2.0   6.0    9.0     2    4
# c  3.0   7.0    3.0     3    9
# d  NaN   8.0   10.0     4   16
# e  9.0  11.0   11.0     5   25

# %%
df4.loc['g'] = [2,3,7,6,9]
df4
# Out:
#    one   two  three  four  six
# a  1.0   5.0    7.0     1    1
# b  2.0   6.0    9.0     2    4
# c  3.0   7.0    3.0     3    9
# d  NaN   8.0   10.0     4   16
# e  9.0  11.0   11.0     5   25
# f  2.0   3.0    4.0     5    6
# g  2.0   3.0    7.0     6    9

# %%
df4.sort_values(['two','three'],ascending=[True,False])
# Out:
#    one   two  three  four  six
# g  2.0   3.0    7.0     6    9
# f  2.0   3.0    4.0     5    6
# a  1.0   5.0    7.0     1    1
# b  2.0   6.0    9.0     2    4
# c  3.0   7.0    3.0     3    9
# d  NaN   8.0   10.0     4   16
# e  9.0  11.0   11.0     5   25

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, a to g
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     6 non-null      float64
#  1   two     7 non-null      float64
#  2   three   7 non-null      float64
#  3   four    7 non-null      int64
#  4   six     7 non-null      int64
# dtypes: float64(3), int64(2)
# memory usage: 656.0+ bytes

# %%
df4.isnull()
# Out:
#      one    two  three   four    six
# a  False  False  False  False  False
# b  False  False  False  False  False
# c  False  False  False  False  False
# d   True  False  False  False  False
# e  False  False  False  False  False
# f  False  False  False  False  False
# g  False  False  False  False  False

# %%
df4.isnull().sum()
# Out:
# one      1
# two      0
# three    0
# four     0
# six      0
# dtype: int64

# %%
df4.shape
# Out:
# (7, 5)

# %%
df4.head(3)
# Out:
#    one  two  three  four  six
# a  1.0  5.0    7.0     1    1
# b  2.0  6.0    9.0     2    4
# c  3.0  7.0    3.0     3    9

# %%
df4.tail(3)
# Out:
#    one   two  three  four  six
# e  9.0  11.0   11.0     5   25
# f  2.0   3.0    4.0     5    6
# g  2.0   3.0    7.0     6    9

# %%
df4.dtypes
# Out:
# one      float64
# two      float64
# three    float64
# four       int64
# six        int64
# dtype: object

# %%
df4['one'].dtype
# Out:
# dtype('float64')

# %%
for ind,row in df4.iterrows():
    print('one : ',row['one'], "two : ", row['two'], " pass" if row['two'] > 5 else "fail")
# Out:
# one :  1.0 two :  5.0 fail
# one :  2.0 two :  6.0  pass
# one :  3.0 two :  7.0  pass
# one :  nan two :  8.0  pass
# one :  9.0 two :  11.0  pass
# one :  2.0 two :  3.0 fail
# one :  2.0 two :  3.0 fail

# %%
df = pd.read_csv('../data/drinks.csv',index_col=0,nrows=10)
df
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# ...

# %%
df = pd.read_csv('../shark.tsv',sep='\t')
df
# Out:
#    Shark Attacks  USA  Australia  South Africa
# 0            Jan   28         94            68
# 1            Feb   27         78            32
# 2            Mar   66         63            34
# 3            Apr  103         54            25
# 4            May  106         21            25
# 5            Jun  173         25            22
# 6            Jul  232         25            28
# 7            Aug  208         28            15
# 8            Sep  182         35            17
# 9            Oct  141         56            16
# 10           Nov   79         65            20
# 11           Dec   37         94            46

# %%
df = pd.read_excel('../Canada.xls',sheet_name=1,skiprows=20,skipfooter=2)
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
df.shape
# Out:
# (195, 43)

# %%
df = pd.read_excel('../Canada.xlsx',sheet_name=1,skiprows=20,skipfooter=2,engine='openpyxl')
df
# Out:
#             Type    Coverage          OdName   AREA AreaName     REG  \
# 0     Immigrants  Foreigners     Afghanistan  935.0     Asia  5501.0
# 1     Immigrants  Foreigners         Albania  908.0   Europe   925.0
# 2     Immigrants  Foreigners         Algeria  903.0   Africa   912.0
# 3     Immigrants  Foreigners  American Samoa  909.0  Oceania   957.0
# 4     Immigrants  Foreigners         Andorra  908.0   Europe   925.0
# ...          ...         ...             ...    ...      ...     ...
# 1008         NaN         NaN             NaN    NaN      NaN     NaN
# 1009         NaN         NaN             NaN    NaN      NaN     NaN
# 1010         NaN         NaN             NaN    NaN      NaN     NaN
# 1011         NaN         NaN             NaN    NaN      NaN     NaN
# 1012         NaN         NaN             NaN    NaN      NaN     NaN
#
#               RegName    DEV             DevName  1980  ...    2012    2013  \
# ...

# %%
df = df.iloc[:195,:43]
df.shape
# Out:
# (195, 43)

# %%
df.head()
# Out:
#          Type    Coverage          OdName   AREA AreaName     REG  \
# 0  Immigrants  Foreigners     Afghanistan  935.0     Asia  5501.0
# 1  Immigrants  Foreigners         Albania  908.0   Europe   925.0
# 2  Immigrants  Foreigners         Algeria  903.0   Africa   912.0
# 3  Immigrants  Foreigners  American Samoa  909.0  Oceania   957.0
# 4  Immigrants  Foreigners         Andorra  908.0   Europe   925.0
#
#            RegName    DEV             DevName  1980  ...    2004    2005  \
# 0    Southern Asia  902.0  Developing regions  16.0  ...  2978.0  3436.0
# 1  Southern Europe  901.0   Developed regions   1.0  ...  1450.0  1223.0
# 2  Northern Africa  902.0  Developing regions  80.0  ...  3616.0  3626.0
# 3        Polynesia  902.0  Developing regions   0.0  ...     0.0     0.0
# 4  Southern Europe  901.0   Developed regions   0.0  ...     0.0     0.0
#
#      2006    2007    2008    2009    2010    2011    2012    2013
# ...
